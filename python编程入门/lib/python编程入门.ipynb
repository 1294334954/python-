# %% [markdown]
# # 1、数据类型
#
# Python中有以下九个基本的数据类型：
#
# ![image.png](attachment:image.png)
# - 整数 int
# - 字符串 str
# - 浮点数 float
# - 集合 set
# - 列表 list
# - 元组 tuple
# - 字典 dict
# - 布尔类型 bool
#
# 其中可变数据类型有：list（列表）、dict（字典）、set（集合）；
# 不可变数据类型有：int（整型）、float（浮点型）、str（字符串）、bool（布尔类型）、tuple（元组）；

# %% [markdown]
# 算术运算符
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 1.1  数字—int整型、float浮点型、bool布尔、complex复数
#
# - 整型（整数，例如42,10000等）
#
# - 浮点型（小数，例如3.1415，或用科学计数法表示的数字1.0e8，是1乘以10的8次方）
#
# - 布尔型（表示真假的类型，仅有Ture和False两种取值）
#
# - 字符串（字符组成的序列）
#
# ### int（整型）
#
# **<font color=red size=3 face="黑体">通常被称为是整型或整数，是正或负整数，不带小数点；**
#
# 创建整型：等号左边是变量名，右边是要赋的值；
#
# a = 100 或 b = -100
#
# 整型数据类型变量前的操作符有：加（＋）、减（－）、乘（）、除（／）和幂（*）；
#
# - 定义一个正整数
#
# ```python
# a = 1
# b = 2
#
# ```

# %% [markdown]
# - 运算
#
# ```python
# #加
# c1 = a + b
# print(c1)  #输出：3
# #减
# c2 = b - a
# print(c2)  #输出：1
# #乘
# c3 = a * b
# print(c3)  #输出：2
# #除
# c4 = a / b
# print(c4)  #输出：0.5
# #幂 - > 相当于a的b次方
# c5 = a ** b
# print(c5)  #输出：1
#
# ```

# %% [markdown]
# ### 浮点型(Float)
# **<font color=red size=3 face="黑体">Python的浮点数就是数学中的小数**
#
# 浮点数也就是小数，之所以称为浮点数，是因为按照科学记数法表示时，一个浮点数的小数点位置是可变的，比如，1.23x10^9和12.3x10^8是相等的。浮点数可以用数学写法，如1.23，3.14，-9.01，等等。但是对于很大或很小的浮点数，就必须用科学计数法表示，把10用e替代，1.23x109就是1.23e9。
# **浮点数运算则可能会有四舍五入的误差。**
# ```python
# f1=1.23
# print(type(f1))
# ```

# %% [markdown]
# ### 布尔类型（Boolean）
# **<font color=red size=3 face="黑体">一个布尔值只有True、False两种值，要么是True，要么是False，在Python中，可以直接用True、False表示布尔值（请注意大小写）**，也可以通过布尔运算计算出来：
#
# ```python
# 代码如下:
#
# True
#
# False
#
# 3 > 2
#
# 3 > 5
#
#
# ```

# %% [markdown]
# #### 布尔值还可以用and、or和not运算。
# 1).and运算是**与**运算，只有所有都为True，and运算结果才是True：
#
#  代码如下:
# ```python
# True and True
#
# True and False
#
# False and False
#
#
# ```

# %% [markdown]
# 2).or运算是**或**运算，只要其中有一个为True，or运算结果就是True：
#  代码如下:
# ```python
# True or True
#
# True or False
#
# False or False
#
# ```

# %% [markdown]
# 3).not运算是**非**运算，它是一个单目运算符，把True变成False，False变成True：
# 代码如下:
# ```python
# not True
#
# not False
#
# ```

# %% [markdown]
# ### 复数( (complex))
# 复数由实数部分和虚数部分构成，可以用a + bj,或者complex(a,b)表示， 复数的实部a和虚部b都是浮点型。
# 例如：
# ```python
# aa=456-20j
# print(aa.real)  # output 实数部分 456.0
# print(aa.imag) # output虚数部分 -20.0
# ```

# %% [markdown]
# ### 字符串(String)
# **<font color=red size=3 face="黑体">字符串由0个或多个字符组成的有序字符序列，可以使用引号('或")来创建**
# 比如 **'abc'，"xyz"** 等等。
#
# ![image.png](attachment:image.png)

# %% [markdown]
#
#
# - 字符串 就是 一串字符，是编程语言中表示文本的数据类型
#
# - 在 Python 中可以使用 一对双引号 " 或者 一对单引号 ' 定义一个字符串

# %% [markdown]
# #### 索引
# ![image.png](attachment:image.png)
#
# ```
# 字符串使用[ ]提取字符
#        有两种索引方式，第一种是从左往右，从0开始依次增加；第二种是从右往左，从-1开始依次减少。
# 使用[头下标:尾下标]分片
#
#        字符串进行切片，获取一段子串。用冒号分隔两个索引，形式为变量[头下标:尾下标]。
# 截取的范围是前闭后开的，并且两个索引都可以省略：
# ```
# ```python
# str='012345'
# str[-6]
# ```

# %% [markdown]
# #### 字符串的运算
#
# ![image.png](attachment:image.png)
#
# ```python
# a = 'Hello'   #用单引号创建字符串
# b = "Python"   #用双引号创建字符串
#
# print("a + b 输出结果：", a + b)  #  用+号拼接字符串
# print("a * 2 输出结果：", a * 2)  #使用*号复制，重复输出字符串
# print("a[1] 输出结果：", a[1])   #使用[]索引获取字符串中字符，正向索引
# print("a[-1] 输出结果：", a[-1])  #负向索引
# print("a[1:4] 输出结果：", a[1:4])   #使用[头下标:尾下标]对字符串进行切片，获取一段字符串
# print ("我叫 %s 今年 %d 岁!" % ('小明', 10))  #字符串格式化输出
#
#
# ```

# %% [markdown]
# ## 1.2 列表
#
# **<font color=red size=3 face="黑体"> 列表是写在方括号之间、用逗号分隔开的元素列表,列表中元素的类型可以不相同.**
#
# 列表是最常用的Python数据类型，它可以作为一个方括号内的逗号分隔值出现。
#
# ![image.png](attachment:image.png)

# %% [markdown]
#
#
#
#
# - 列表的数据项不需要具有相同的类型
#
# - 创建一个列表，只要把逗号分隔的不同的数据项使用方括号括起来即可。
#
# 如下所示：
# ```python
# 1.创建列表
#
# list1 = ['Google', 1997, 2000];
# list2 = [1, 2, 3, 4, 5 ];
# list3 = ["a", "b", "c", "d"];
#
# 2.使用下标索引来访问列表中的值
#
# print ("list1[0]: ", list1[0])
#
#  使用方括号的形式截取字符
# print ("list2[1:5]: ", list2[1:5])
#
# 3.列表的数据项进行修改或更新
#
# print ("第二个元素为 : ", list1[1])
# list1[1] = 2001
# print ("更新后的第二个元素为 : ", list1[1])
#
# ```

# %% [markdown]
# ```python
#
# 4.用 del 语句删除列表元素
#
# print ("原始列表 : ", list1)
# del list1[1]
# print ("删除第二个元素 : ", list1)
#
#
# 5. 用len（）获取列表长度
# len(list1)
#
# 6. + 号用于组合列表
# [1, 2, 3] + [4, 5, 6]
#
# 7. * 号用于重复列表
# ['Hi!'] * 4
#
# 8.in判断元素是否存在于列表中
# 3 in [1, 2, 3]
#
# 9.使用嵌套列表即在列表里创建其它列表
# a = ['a', 'b', 'c']
# n = [1, 2, 3]
# x = [a, n]
# x
# x[0]
# x[0][1]
#
# ```

# %% [markdown]
# - 内建函数使用
#
# ```python
# test = ['shanghai', 'nanjing', 'hangzhou']
# test[0] = 'beijing'       # 修改列表元素
# print(test)
#
# test.append('beijing')    # 在列表末尾添加元素
# print(test)
#
# test.insert(2, 'beijing')  # 在列表中插入元素，第一个参数：在列表中插入的位置
# print(test)
#
# del test[1]              # 使用del删除元素，要知道删除元素在列表中的位置（del后面是空格）
# print(test)
#
# popped_test = test.pop()    #方法pop()可删除列表末尾的元素，并让你能够接着使用它
# print(test)
# print(popped_test)
#
# popped_test = test.pop(2)   #弹出列表中任何位置的元素，（）中是索引
# print(test)
# print(popped_test)
#
# test.remove('beijing')         # 根据名称删除元素，（不知道元素在列表中哪个位置）
# print(test)
#
# ```

# %% [markdown]
# ##  1.3 元组
#
# - Python的元组与列表类似，不同之处在于元组的元素不能修改。
#
# - 元组使用小括号，列表使用方括号。
#
# - 元组创建很简单，只需要在括号中添加元素，并使用逗号隔开即可。
#
# ```python
#
#
# # 创建元组
# tup1 = ('physics', 'chemistry', 1997, 2000)
# tup2 = (1, 2, 3, 4, 5, 6, 7)
# tup3 = ("a",)  # 只有一个元素的元组
# tup4 = ()  # 空元组
#
# # 访问元组
# print ("tup1[0]: ", tup1[0])
# print ("tup2[1:5]: ", tup2[1:5])
#
# # +号拼接
# tup5 = tup1 + tup2
# print(tup5)
#
#
#
#
# ```

# %% [markdown]
# ##  1.4 集合
# **<font color=red size=3 face="黑体">集合（set）是一个无序不重复元素的集。基本功能是进行成员关系测试和消除重复元素。**
#
# ```python
# student = {'Tom','Jim','Mary','Tom','Jack','Rose'}
# print(student) #重复的元素会被自动去掉
#
#
# 'Rose' in student #成员测试
# ```
# 可以使用大括号 或者 set()函数创建set集合：
#
# 注意：创建一个空集合必须用 set() 而不是 { }，因为{ }是用来创建一个空字典。
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ```python
# #set可以进行集合运算
# a = set('abracadabra')
# b = set('alacazam')
#
#
# print(a)
#
# print(a-b)   #a和b的差集
#
# print(a|b)     #a和b的并集
#
# print(a & b)   #a和b的交集
#
# print(a ^ b)   #a和b中不同时存在的元素
# ```

# %% [markdown]
# ## 1.5 字典
# **字典是python语言中唯一的映射类型。**
# 字典是一些列键（key）值（value）对组成的，形式如下：
#        **{ 键1：值1，键2,：值2 }**
# - 每个键值对用冒号隔开
# - 每对之间用逗号隔开
# - 键必须是唯一的，必须是不可变的
# * 如字符串，数字，元组.值可以是任何数据类型
#
# 字典值可以没有限制地取任何python对象，既可以是标准的对象，也可以是用户定义的，但键不行，键有两个特性：
#
# 1）不允许同一个键出现两次。创建时如果同一个键被赋值两次，后一个值会被记住，
# 2）键必须不可变，所以可以用数字，字符串或元组充当，但用元组做有效的键，必须要加限制：元组中只包括像数字和字符串这样的不可变参数。
#
#
# ```python
# # 创建
# dict = {'Name': 'Zara', 'Age': 7, 'Class': 'First'}
# dict1 = {'abc': 456, 88: 'ok'}
# dict2 = {'a': 1, 'b': dict1, 'c': [1, 2, 3]}
#
# # 访问
# print(dict2.values())
# print("dict['Name']: ", dict['Name'])
#
# ```

# %% [markdown]
# ```python
#
# #更新
# dict['Age'] = 8
# print("dict['Age']: ", dict['Age'])
#
# # 添加
# dict['School'] = "DPS School"
# print("dict['School']: ", dict['School'])
#
# # 重定义
# dict3 = {'Name': 'Alice', 'Age': 10, 'Class': 'Second', 'School': 'DPS School'}
# dict.update(dict3)
# print ("The dict after fully update: ", dict)
#
# ```

# %% [markdown]
# ```python
# # 删除一对
# del dict['School']
# print (dict)
# # 清除
# dict.clear()
# print (dict)
# # 删除
# del dict1
# print(dict1)
#
# ```

# %% [markdown]
# # 2、控制流程
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 赋值语句
# 赋值语句：由赋值符号构成的一行代码，等号（=）用来给变量赋值
#
# 等号（=）运算符左边是一个变量名,等号（=）运算符右边是存储在变量中的值
#
# ![image.png](attachment:image.png)

# %% [markdown]
#
#
#
# ## 2.1  if语句
# **条件控制：由判断条件决定程序运行方向的语句 ；
# if 语句用于控制程序的执行，基本形式为：**
#
# ![image.png](attachment:image.png)
#
# ```
#
#
# 注意：代码的缩进为一个 tab 键，或者 4 个空格 —— 建议使用空格，在 Python 开发中，Tab 和空格不要混用！
#
# 我们可以把整个 if 语句看成一个完整的代码块
#
# ```
#
# ```python
#
# age = int(input("age: "))
# if age < 17:
#     print('你不能买酒，要来包口香糖吗')
# else :
#     print('要买几瓶')
#
# ```

# %% [markdown]
# ## 2.2 程序的三大流程
#
# 在程序开发中，一共有三种流程方式：**
# * 顺序 —— 从上向下，顺序执行代码
# * 分支 —— 根据条件判断，决定执行代码的 分支
# * 循环 —— 让 特定代码 重复 执行
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 分支结构
#
# 分支结构就是if语句通过判断条件是否成立来决定是否执行某个语句
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### if-else语句
#
# if-else语句就是在原有的if成立执行操作的基础上，当不成立的时候，也执行另一种操作
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### if-elif-else语句
#
# 这种语句是处理可能有多种情况的判断
# ![image.png](attachment:image.png)
#
# 例：
#
# ```python
# age = int(input("狗的年龄: "))
# print()
# if age < 0:
#     print("不太可能!")
# elif age == 1:
#     print("大约等于14岁!")
# elif age == 2:
#     print("大约等于22岁!")
# elif age > 2:
#     human = 22 + (age - 2)*5
#     print("人类年龄:",human)
#
# ```

# %% [markdown]
# ### 循环结构
#
# 循环语句允许我们执行一个代码或代码组多次，下面是在大多数编程语言中的循环语句的一般形式：
#
# **Python中的循环语句有 for 和 while**
# ![image.png](attachment:image.png)

# %% [markdown]
# ##  for语句流程
#
# for循环可以遍历任何序列的项目，如一个列表或者一个字符串
# ![image.png](attachment:image.png)
#
# - 例
#
# ```python
#
# words = ['cat', 'window', 'defenestrate']
# for w in words:
#     print(w, len(w))
#
# ```

# %% [markdown]
# ##  while语句流程
# **while 语句用于循环执行程序，即在某条件下，循环执行某段程序，以处理需要重复处理的相同任务。执行语句可以是单个语句或语句块。判断条件可以是任何表达式，任何非零、或非空（null）的值均为true。当判断条件假false时，循环结束。**
# ![image.png](attachment:image.png)
#
# - 循环输出
#
# ```python
# # 1. 定义重复次数计数器
# i = 1
#
# # 2. 使用 while 判断条件
# while i <= 5: # 要重复执行的代码
#     print("Hello Python") # 处理计数器 i
#     i = i + 1
#
# print("循环结束后的 i = %d" % i)
#
# ```

# %% [markdown]
# - 求和
#
# ```python
# # 计算 0 ~ 100 之间所有数字的累计求和结果
# # 定义最终结果的变量
# i = 0
#
# # 定义一个整数的变量记录循环的次数
# sum = 0
#
# #  开始循环
# while i <= 100:
# #   print(i)  #每一次循环，都让 result 这个变量和 i 这个计数器相加
#
#     sum += i
#
#     i += 1  #处理计数器
#
# print("0~100之间的数字求和结果 = %d" % sum)
#
# ```

# %% [markdown]
# ## break 和 continue
# **break 和 continue 是专门在循环中使用的关键字**
# - break 某一条件满足时，退出循环，不再执行后续重复的代码
# - continue 某一条件满足时，不执行后续重复的代码
# **break 和 continue 只针对 当前所在循环 有效**
#
# ###  break
# * 在循环过程中，如果 某一个条件满足后，不 再希望 循环继续执行，可以使用 break 退出循环
#
#
# - 例
#
# ```python
# i = 0
#
# while i < 10:
#     # break 某一条件满足时，退出循环，不再执行后续重复的代码
#     # i == 3
#     if i == 3:
#         break
#
#     print(i)
#
#     i += 1
#
# print("over")
#
# ```

# %% [markdown]
# ### continue
# - 在循环过程中，如果 某一个条件满足后，不 希望 执行循环代码，但是又不希望退出循环，可以使用 continue
# - 也就是：在整个循环中，只有某些条件，不需要执行循环代码，而其他条件都需要执行
# - 例
#
# ```python
# i = 0
#
# while i < 10:
#     # 当 i == 7 时，不希望执行需要重复执行的代码
#     if i == 7:
#         # 在使用 continue 之前，同样应该修改计数器
#         # 否则会出现死循环
#         i += 1
#
#         continue
#
#     # 重复执行的代码
#     print(i)
#
#     i += 1
# ```

# %% [markdown]
# # 3、Python函数
#
#
# - 所谓函数，就是把 具有独立功能的代码块 组织为一个小模块，在需要的时候 调用
# - 函数的使用包含两个步骤：
# 1.定义函数 —— 封装 独立的功能
# 2.调用函数 —— 享受 封装 的成果
# - 函数的作用，在开发程序时，使用函数可以提高编写的效率以及代码的 重用
#
# 函数是由函数名、参数和函数体组成，格式如下：
# ![image.png](attachment:image.png)
# - 例
#
# ```python
# #第一个函数
# def hello():
#     print("hello world")
# hello()
# ```

# %% [markdown]
# - 例
#
# ```python
# name = "小明"
#
# # 解释器知道这里定义了一个函数
# def say_hello():
#     print("hello 1")
#     print("hello 2")
#     print("hello 3")
#
# print(name)
# # 只有在调用函数时，之前定义的函数才会被执行
# # 函数执行完成之后，会重新回到之前的程序中，继续执行后续的代码
# say_hello()
#
# print(name)
#
# ```

# %% [markdown]
# #### 返回值
#
# 是函数 完成工作后，最后 给调用者的 一个结果，以便调用者针对具体的结果做后续的处理。
#
# 在函数中使用 **return** 关键字可以返回结果
#
# - 对两个数字求和
#
# ```python
# def sum_2_num(num1, num2):
#     return num1 + num2
#     # 调用函数，并使用 result 变量接收计算结果
# result = sum_2_num(10, 20)
# print("计算结果是 %d" % result)
# ```

# %% [markdown]
# #### 函数变量作用域
# 定义在函数内部的变量拥有一个局部作用域，定义在函数外的拥有全局作用域。
# - 例
#
# ```python
# a=4
# def print_func1():
#     a=17
#     print("in print_func a =",a)
# def print_func2():
#     print("in print_func2 a =",a)
# print_func1()
# print_func2()
# print("a = ",a)
# ```

# %% [markdown]
# # 4、Python模块
#
#
# 模块是一个包含所有你定义的函数和变量的文件，其后缀名是.py。模块可以被别的程序引入，以使用该模块中的函数等功能。
#
# **1 模块的概念**
# 模块是 Python 程序架构的一个核心概念
# 每一个以扩展名 py 结尾的 Python 源代码文件都是一个 模块
# 模块名 同样也是一个 标识符，需要符合标识符的命名规则
# 在模块中定义的 全局变量 、函数、类 都是提供给外界直接使用的 工具
# 模块 就好比是 工具包，要想使用这个工具包中的工具，就需要先 导入 这个模块
# **2 模块的两种导入方式**
# > 1）import 导入
#        import 模块名1, 模块名2
# 提示：在导入模块时，每个导入应该独占一行
# import 模块名1
# import 模块名2
# - 导入之后
#  通过 模块名. 使用 模块提供的工具 —— 全局变量、函数、类
# 使用 as 指定模块的别名
# 如果模块的名字太长，可以使用 as 指定模块的名称，以方便在代码中的使用
# import 模块名1 as 模块别名
# 注意：模块别名 应该符合 大驼峰命名法
#
# > 2）from...import 导入
# - 如果希望 从某一个模块 中，导入 部分 工具，就可以使用 from ... import 的方式
# - import 模块名 是 一次性 把模块中 所有工具全部导入，并且通过 模块名/别名 访问
# 从 模块 导入 某一个工具
# from 模块名1 import 工具名
# - 导入之后
# 不需要 通过 模块名.
# 可以直接使用 模块提供的工具 —— 全局变量、函数、类
#
# - 例
#
# ```python
# import random
#
# # 生成一个 0～10 的数字
# rand = random.randint(0, 10)
#
# print(rand)
#
# ```

# %% [markdown]
# # 5、Python异常
#
# 即便Python程序的语法是正确的，在运行它的时候，也有可能发生错误。运行期检测到的错误被称为异常。
#
# 大多数的异常都不会被程序处理，都以错误信息的形式展现在这里:
#
# Python 的语法错误或者称之为解析错，是初学者经常碰到的。
# ![image.png](attachment:image.png)
# 函数 print() 被检查到有错误，是它前面缺少了一个冒号（:）。
#
# ```python
# while True:
#     print('Hello World')
#
# ```
# 语法分析器指出了出错的一行，并且在最先找到的错误的位置标记了一个小小的箭头。

# %% [markdown]
# **常见异常**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 6、简单使用第三方库使用——NumPy
#
# NumPy(Numerical Python) 是 Python 语言的一个扩展程序库，支持大量的维度数组与矩阵运算，此外也针对数组运算提供大量的数学函数库。
#
# NumPy 的前身 Numeric 最早是由 Jim Hugunin 与其它协作者共同开发，2005 年，Travis Oliphant 在 Numeric 中结合了另一个同性质的程序库 Numarray 的特色，并加入了其它扩展而开发了 NumPy。NumPy 为开放源代码并且由许多协作者共同维护开发。
#
# NumPy 是一个运行速度非常快的数学库，主要用于数组计算，包含：
#
# 一个强大的N维数组对象 ndarray。
#
# 广播功能函数。
#
# 整合 C/C++/Fortran 代码的工具。
#
# 线性代数、傅里叶变换、随机数生成等功能。
# ![image.png](attachment:image.png)
# NumPy 官网 http://www.numpy.org/

# %% [markdown]
# ## 6.1 NumPy Ndarray 对象
# NumPy 最重要的一个特点是其 N 维数组对象 ndarray，它是一系列同类型数据的集合，以 0 下标为开始进行集合中元素的索引。
#
# ndarray 对象是用于存放同类型元素的多维数组。
#
# ndarray 中的每个元素在内存中都有相同存储大小的区域。
#
# ndarray 内部由以下内容组成：
#
# 一个指向数据（内存或内存映射文件中的一块数据）的指针。
#
# 数据类型或 dtype，描述在数组中的固定大小值的格子。
#
# 一个表示数组形状（shape）的元组，表示各维度大小的元组。
#
# 一个跨度元组（stride），其中的整数指的是为了前进到当前维度下一个元素需要"跨过"的字节数。
#
# 创建一个 ndarray 只需调用 NumPy 的 array 函数即可：
# ```python
# numpy.array(object, dtype = None, copy = True, order = None, subok = False, ndmin = 0)
#
# ```
# ![image.png](attachment:image.png)
# ```python
# import numpy as np
# lst=[[1,2,3],[4,5,6]]#二维
# print(type(lst))#查看类型
# np_lst=np.array(lst)
# print(type(np_lst))#numpy.ndarray 最基础的数据结构
# np_lst=np.array(lst,dtype=np.float) #将lst定义为浮点型
# print(np_lst.shape) #返回（2，3），表示np_lst为两行三列
# print(np_lst.ndim) #表示维度为2
# print(np_lst.dtype) #数据类型为浮点型
# print(np_lst.size) # 元素个数为6
#
# ```

# %% [markdown]
# ## 6.2 NumPy 常用函数之arange函数
#
# np.arange([start, ]stop, [step, ]dtype=None)
#
# arange函数用于创建等差数组
#
# start:可忽略不写，默认从0开始;起始值
#
# stop:结束值；生成的元素不包括结束值
#
# step:可忽略不写，默认步长为1；步长
#
# dtype:默认为None，设置显示元素的数据类型
#
# ```python
# import numpy as np
# nd1 = np.arange(5)#array([0, 1, 2, 3, 4])
# print(nd1)
# nd2 = np.arange(1,5)#array([1, 2, 3, 4])
# print(nd2)
# nd3 = np.arange(1,9,2)
# print(nd3)
# ```

# %% [markdown]
# # 现学现用小游戏
#
# 设计一个0-100猜数字小程序。
#
# 要求：
#
# 1.游戏开始时随机生成一个数字，一共有5次输入机会。
#
# 2.输入数字后会提示输入数字与答案相比偏大还是偏小。
#
# 3.若5次输入全部错误，则会结束游戏。
#
# 提示：int, input, randint, for/while, if, break, print
